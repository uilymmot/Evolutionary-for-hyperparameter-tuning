# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import cv2
import pandas as pd
import math
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torch.nn.functional as F
# %config IPCompleter.greedy=True
from sklearn.metrics import precision_recall_fscore_support
import copy

tseed = 19
npseed = 16
torch.manual_seed(tseed)
np.random.seed(npseed)

# %%
# data load dataset

data = np.genfromtxt('Data.csv', delimiter=',', dtype=str)

processedData = np.zeros((data.shape[0] - 2, data.shape[1] - 1))
processedData = data[2:data.shape[0]-1,1:]

# np.random.shuffle(processedData)

processedData = processedData.astype(np.float)

def circularEncode(data):
    newDataS = np.zeros(data.shape)
    newDataC = np.zeros(data.shape)
    sVal = 0
    cVal= np.pi
    for u in np.unique(data):
        s = np.sin(sVal) 
        c = np.cos(sVal) 
        if ((s < 0.0001 and s > 0) or (s > -0.0001 and s < 0)):
            s = 0
        if ((c < 0.0001 and c > 0) or (c > -0.0001 and c < 0)):
            c = 0
    
        newDataS[data == u] = s
        newDataC[data == u] = c
        sVal += (np.pi / 4)
        cVal += (np.pi / 4)
        
    newDataS = newDataS + 1
    newDataC = newDataC + 1
    newDataS /= 2
    newDataC /= 2
    
    return newDataS, newDataC

grainSize = processedData[:,1:12]
sorting = processedData[:,13:20]
matrix = processedData[:,21:36]
roundness = processedData[:,37:45]
bioturbation = processedData[:,46:49]
laminae = processedData[:,50:59]

totalSum = np.sum(grainSize, axis=1) + np.sum(sorting, axis=1) + np.sum(matrix, axis=1) + np.sum(roundness, axis=1)  + np.sum(bioturbation, axis=1) + np.sum(laminae, axis=1) 

sinencodingRoundness, cosencodingRoundness = circularEncode(np.argmax(roundness, axis=1))

compiledProcessedData = np.zeros((8,226))
compiledProcessedData[0] = processedData[:,0]
compiledProcessedData[1] = np.argmax(grainSize, axis = 1) 
compiledProcessedData[2] = np.argmax(sorting, axis=1) 
compiledProcessedData[3] = np.argmax(matrix, axis=1) 
compiledProcessedData[4] = sinencodingRoundness
compiledProcessedData[5] = cosencodingRoundness
compiledProcessedData[6] = np.argmax(bioturbation, axis=1) 
compiledProcessedData[7] = np.argmax(laminae, axis=1)

# Normalise all values in the range 0-1
for i in range(1, compiledProcessedData.shape[0]):
    if (np.max(compiledProcessedData[i]) > 1):
        compiledProcessedData[i] = compiledProcessedData[i] / np.max(compiledProcessedData[i])

# Create the 4 porosity classes
porosityClasses = np.copy(compiledProcessedData[0])
porosityClasses[compiledProcessedData[0] >= 15] = 3
porosityClasses[(compiledProcessedData[0] >= 10) & (compiledProcessedData[0] < 15)] = 2
porosityClasses[(compiledProcessedData[0] >= 5) & (compiledProcessedData[0] < 10)] = 1
porosityClasses[compiledProcessedData[0] < 5] = 0

compiledProcessedData[0] = porosityClasses

cprocessedData = compiledProcessedData[:,totalSum > 3]

compiledProcessedData = cprocessedData.T

# np.random.shuffle(compiledProcessedData)
print(compiledProcessedData[0:3])

# compiledProcessedData = pd.DataFrame(compiledProcessedData)
# print(compiledProcessedData)

np.random.shuffle(compiledProcessedData)

train_data = compiledProcessedData[:109]
test_data = compiledProcessedData[109:]

# split training data into input and target
train_input = train_data[:, 1:]
train_target = train_data[:, 0]

# split training data into input and target
# the first 9 columns are features, the last one is target
test_input = test_data[:, 1:]
test_target = test_data[:, 0]

# create Tensors to hold inputs and outputs
X = Variable(torch.Tensor(train_input))
Y = Variable(torch.Tensor(train_target))

X1 = Variable(torch.Tensor(test_input))
Y1 = Variable(torch.Tensor(test_target))

print(X.shape, X1.shape)
# Out:
# [[3.         1.         0.33333333 0.         0.5        1.
#   0.         0.        ]
#  [3.         1.         0.33333333 0.         0.5        1.
#   0.         0.        ]
#  [3.         1.         0.33333333 0.         0.5        1.
#   0.         0.        ]]
# torch.Size([109, 7]) torch.Size([50, 7])

# %%
def validationAccuracy(tmodel, valsetX, valSetY):
    predTest = np.argmax(tmodel(valsetX).detach().numpy(), axis=1)
    targetTest = valSetY.numpy()
    testConfusion = confusion_matrix(targetTest, predTest)
    results = precision_recall_fscore_support(predTest, targetTest)
    return np.mean(results[2])

# %%
nnHypers = dict()
nnHypers['lr'] = 0.08
nnHypers['neurons'] = np.array([25, 30])
nnHypers['dropout'] = np.array([0, 0.25])
nnHypers['bias'] = True
nnHypers['epochs'] = 2500
nnHypers['inputsize'] = train_input.shape[1]
nnHypers['activation'] = 6
nnHypers['outputsize'] = 4
nnHypers['lasthidden'] = 30

possibleActivations = [']

# %%
# Defines a custom neural network depending on a dictionary of hyperparameters given
def constructNetworkFromNNHyperparams(nnHyperParams):
    class HyperNetwork(nn.Module):
        def __init__(self):
            super(HyperNetwork, self).__init__()
            self.hidden = nn.ModuleList()
            self.drops = nn.ModuleList()
            for i in range(0, nnHyperParams['neurons'].shape[0]):
                self.hidden.append(torch.nn.Linear(nnHyperParams['inputsize'], nnHyperParams['neurons'][i], nnHyperParams['bias']))
            for i in range(0, nnHyperParams['dropout'].shape[0]):
                self.drops.append(torch.nn.Dropout(nnHyperParams['dropout'][i]))
        
            self.out = torch.nn.Linear(nnHyperParams['lasthidden'], nnHyperParams['outputsize'])

        def forward(self, x):
            l1 = x
            for i in range(0, nnHyperParams['neurons'].shape[0]):
                l1 = possibleActivations[nnHyperParams['activation']](self.hidden[i](x))
                if (i < nnHyperParams['dropout'].shape[0]):
                    l1 = self.drops[i](l1)
            l2 = self.out(l1)
            return l2
    return HyperNetwork()

def trainAndEvalNetwork(nnHyperParams, trainSetX, trainSetY, valsetX, valSetY):
    modell = constructNetworkFromNNHyperparams(nnHyperParams)
    loss_func = nn.CrossEntropyLoss()
    optimiser = torch.optim.SGD(modell.parameters(), lr=nnHyperParams['lr'])
    
    all_losses = []

    plt.ion()
    
    for t in range(nnHyperParams['epochs']):
        # clear gradients for next train
        optimiser.zero_grad()
        # pass input x and get prediction
        prediction = modell.forward(trainSetX)
        # calculate loss
        loss = loss_func(prediction, trainSetY.long())
        # perform backward pass
        loss.backward()
        # call the step function on an Optimiser makes an update to its
        # parameters
        optimiser.step()
    modell.eval()
    
    return validationAccuracy(modell, valsetX, valSetY)

def trainNetwork(nnHyperParams, trainSetX, trainSetY):
    modell = constructNetworkFromNNHyperparams(nnHyperParams)
    loss_func = nn.CrossEntropyLoss()
    optimiser = torch.optim.SGD(modell.parameters(), lr=nnHyperParams['lr'])
    
    all_losses = []

    plt.ion()
    
    for t in range(nnHyperParams['epochs']):
        # clear gradients for next train
        optimiser.zero_grad()
        # pass input x and get prediction
        prediction = modell.forward(trainSetX)
        # calculate loss
        loss = loss_func(prediction, trainSetY.long())
        # perform backward pass
        loss.backward()
        # call the step function on an Optimiser makes an update to its
        # parameters
        optimiser.step()
    modell.eval()
    return modell

# %%
def mutateNetwork(nnHyperParameters):
    # we can mutate lr, neurons in a layer, number of layers, dropouts, epochs

    newNNHypers = copy.deepcopy(nnHyperParameters)
    # make random no of mutations (one or two)
    noMutations = np.random.randint(1,3)
    for i in range(0,noMutations):
        itemToMutate = np.random.randint(0, 7)

        upOrDown = np.random.randint(0,2)
    # Change the learning rate of the network
        if (itemToMutate == 0):
            changeLRAmount = np.random.random() * 0.02   
            if (upOrDown == 0):
                newNNHypers['lr'] += changeLRAmount
            else:
                newNNHypers['lr'] -= changeLRAmount

            if (newNNHypers['lr'] <= 0.01):
                newNNHypers['lr'] = 0.01 + changeLRAmount
        # modifies a random dropout layer
        elif (itemToMutate == 1):
            layerToModify = np.random.randint(0, newNNHypers['dropout'].shape[0])

            newNNHypers['dropout'][layerToModify] = np.random.random() * 0.75
                
        # Change the number of neurons within a given layer of the network
        elif (itemToMutate == 2 or itemToMutate == 1):
            layerToMutate = np.random.randint(newNNHypers['neurons'].shape[0])
            currentNoNeurons = newNNHypers['neurons'][layerToMutate]
            neuronChange = int(float(currentNoNeurons / 3) * np.random.random())

            if (upOrDown == 0):
                newNNHypers['neurons'][layerToMutate] += neuronChange
            else:
                newNNHypers['neurons'][layerToMutate] -= neuronChange

            if (newNNHypers['neurons'][layerToMutate] < 7):
                newNNHypers['neurons'][layerToMutate] = 7 + neuronChange
        # add or remove a layer from the network
        elif (itemToMutate == 3):
            newNeuronLayer = np.random.randint(10, 50)

            if (upOrDown == 0 or newNNHypers['neurons'].shape[0] == 1):
                newNNHypers['neurons'] = np.append(newNNHypers['neurons'], newNeuronLayer)
                newNNHypers['lasthidden'] = newNeuronLayer
                newNNHypers['dropout'] = np.append(newNNHypers['dropout'], 0)
            else:
                currentLayers = newNNHypers['neurons']
                removedLayer = np.random.randint(0, currentLayers.shape[0])
                newNNHypers['neurons'] = np.delete(currentLayers, removedLayer)
                newNNHypers['dropout'] = np.delete(newNNHypers['dropout'], removedLayer)
        # increase or decrease the number of epochs the network trains for
        elif (itemToMutate == 4):
            epochsToChange = np.random.randint(250, 500)

            if (upOrDown):
                newNNHypers['epochs'] += epochsToChange
            else:
                newNNHypers['epochs'] -= epochsToChange

            if (newNNHypers['epochs'] < 100):
                newNNHypers['epochs'] = 100 + epochsToChange
            elif (newNNHypers['epochs'] > 3000):
                newNNHypers['epochs'] = 3000 - epochsToChange
        elif (itemToMutate == 5):
            newNNHypers['bias'] = not newNNHypers['bias']
        elif (itemToMutate == 6):
            randomActivation = np.random.randint(0, len(possibleActivations))
            newNNHypers['activation'] = randomActivation
    
    # Update the last layer statistics so that our network handles it properly
    
    newNNHypers['lasthidden'] = newNNHypers['neurons'][newNNHypers['neurons'].shape[0] - 1]
    
    return newNNHypers

def crossOverNetworks(NNHyperP1, NNHyperP2):
    NNHyperOffspring = dict()
    
    NNHyperOffspring['lr'] = NNHyperP1['lr'] if (np.random.randint(0,2) == 0) else NNHyperP2['lr']
    lay = np.random.randint(0,2)
    NNHyperOffspring['neurons'] = NNHyperP1['neurons'] if (lay == 0) else NNHyperP2['neurons']
    NNHyperOffspring['dropout'] = NNHyperP1['dropout'] if (lay == 0) else NNHyperP2['dropout']
    NNHyperOffspring['bias'] = NNHyperP1['bias'] if (np.random.randint(0,2) == 0) else NNHyperP2['bias']
    NNHyperOffspring['epochs'] = int((NNHyperP1['epochs'] + NNHyperP2['epochs']) / 2)
    NNHyperOffspring['inputsize'] = train_input.shape[1]
    NNHyperOffspring['outputsize'] = 4
    NNHyperOffspring['activation'] = NNHyperP1['activation'] if (np.random.randint(0,2) == 0) else NNHyperP2['activation']
    NNHyperOffspring['lasthidden'] = NNHyperOffspring['neurons'][NNHyperOffspring['neurons'].shape[0] - 1]
    
    return NNHyperOffspring

# %%
def randomHyperNetwork(): 
    NNHy = dict()
    NNHy['lr'] = (np.random.random() * 0.1) + 0.02
    noLayers = np.random.randint(1,3)
    NNHy['neurons'] = list()
    for i in range(0, noLayers):
        NNHy['neurons'].append(np.random.randint(10,50))
    NNHy['neurons'] = np.array(NNHy['neurons'])
    
    NNHy['dropout'] = list()
    for i in range(0, noLayers):
        NNHy['dropout'].append(np.random.random() * np.random.random())
    NNHy['dropout'] = np.array(NNHy['dropout'])
    NNHy['bias'] = True
    NNHy['epochs'] = np.random.randint(250, 2500)
    NNHy['inputsize'] = train_input.shape[1]
    
    NNHy['outputsize'] = 4
    NNHy['lasthidden'] = NNHy['neurons'][NNHy['neurons'].shape[0] - 1]
    NNHy['activation'] = np.random.randint(0, len(possibleActivations))
    
    return NNHy

# %%
torch.manual_seed(tseed)
np.random.seed(npseed)

hallOfFame = list()
meanScoresAtEachEpoch = list()
stdScoresAtEachEpoch = list()

def evolutional(number_epochs):
    currentEpochNeuralNets = list()
    for i in range(0,8):
        currentEpochNeuralNets.append(randomHyperNetwork())
    currentBestNetwork = currentEpochNeuralNets[0]
    currentBestNetworkScore = 0
   
    folds = 3
    
    validationSetsX = list()
    validationSetsY = list()
    trainSetsX = list()
    trainSetsY = list()
        
    
    for i in range(0,folds):
        np.random.shuffle(train_data)
        np.random.shuffle(train_data)
        training, test = train_data[:90,:], train_data[90:,:]
        trainSetsX.append(Variable(torch.Tensor(training[:, 1:])))
        trainSetsY.append(Variable(torch.Tensor(training[:, 0])))
        validationSetsX.append(Variable(torch.Tensor(test[:,1:])))
        validationSetsY.append(Variable(torch.Tensor(test[:,0])))
    
    for epoc in range(number_epochs): 
        scores = list()
        for i in range(0, 8):
            currentAverage = 0
            for j in range(0,folds):
                currentAverage += trainAndEvalNetwork(currentEpochNeuralNets[i], trainSetsX[j], trainSetsY[j], validationSetsX[j], validationSetsY[j])
            scores.append((currentAverage / folds))
            print(currentEpochNeuralNets[i]," Model, ", i, ' achieved ', scores[i], ' score')
        scores = np.array(scores)
        ind = np.argpartition(scores, -3)[-3:]
        ind = ind[np.argsort(scores[ind])]
        print("Winners of epoch ", epoc, ":", ind)
        
        if (scores[ind[0]] > currentBestNetworkScore):
            currentBestNetwork = currentEpochNeuralNets[ind[0]]
            
        newEpochNeuralNets = list()
        
        nnetone = currentEpochNeuralNets[ind[2]]
        nnettwo = currentEpochNeuralNets[ind[1]]
        nnetthree = currentEpochNeuralNets[ind[0]]

        hallOfFame.append(nnetone)
        meanScoresAtEachEpoch.append(np.mean(scores))
        stdScoresAtEachEpoch.append(np.std(scores))
        
        newEpochNeuralNets.append(nnetone)
        newEpochNeuralNets.append(crossOverNetworks(nnetone, nnettwo))
        newEpochNeuralNets.append(crossOverNetworks(nnetone, nnettwo))
        newEpochNeuralNets.append(crossOverNetworks(nnetone, nnetthree))
        newEpochNeuralNets.append(nnettwo)
        newEpochNeuralNets.append(crossOverNetworks(nnettwo, nnetthree))
        newEpochNeuralNets.append(mutateNetwork(nnetthree))
        newEpochNeuralNets.append(randomHyperNetwork())
        
        pMutate = (number_epochs - epoc) / number_epochs
        print("Probability of mutating is: ", pMutate)
        for i in range(1, 8):
            chance = np.random.random()           
            if (chance < pMutate):
                newEpochNeuralNets[i] = mutateNetwork(newEpochNeuralNets[i])
        
        currentEpochNeuralNets = newEpochNeuralNets

    return currentBestNetwork

bestNet = evolutional(150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-53555223fbd9> in <module>
#      76     return currentBestNetwork
#      77
# ---> 78 bestNet = evolutional(150)
#
# <ipython-input-11-53555223fbd9> in evolutional(number_epochs)
#       9     currentEpochNeuralNets = list()
#      10     for i in range(0,8):
# ---> 11         currentEpochNeuralNets.append(randomHyperNetwork())
#      12     currentBestNetwork = currentEpochNeuralNets[0]
#      13     currentBestNetworkScore = 0
#
# <ipython-input-10-4130d80c7e60> in randomHyperNetwork()
#      18     NNHy['outputsize'] = 4
#      19     NNHy['lasthidden'] = NNHy['neurons'][NNHy['neurons'].shape[0] - 1]
# ---> 20     NNHy['activation'] = np.random.randint(0, len(possibleActivations))
#      21
#      22     return NNHy
#
# NameError: name 'possibleActivations' is not defined

# %%
testScores = list()
for i in hallOfFame:
    torch.manual_seed(tseed)
    np.random.seed(npseed)
    testScores.append(testModel(trainNetwork(i, X, Y)))

testModel(trainNetwork(bestNet, X, Y))
# Out:
# {'lr': 0.1431172439962126, 'neurons': array([46]), 'dropout': array([0.03784352]), 'bias': False, 'epochs': 1685, 'inputsize': 7, 'outputsize': 4, 'activation': 6, 'lasthidden': 46}
# [[13 10  1  1]
#  [ 5 24  5  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.85257985257985 %
# Average recall is: 66.15829346092504 %
# Average f1-score is: 64.39886284225906 %
#
# [[ 7  4  0  0]
#  [ 2  2  3  3]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.55194805194805 %
# Average recall is: 44.94321468005678 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 43.741765480895914 %
# [[13 10  1  1]
#  [ 5 24  5  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.85257985257985 %
# Average recall is: 66.15829346092504 %
# Average f1-score is: 64.39886284225906 %
#
# [[ 7  4  0  0]
#  [ 2  2  3  3]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.55194805194805 %
# Average recall is: 44.94321468005678 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 43.741765480895914 %
# [[13 10  1  1]
#  [ 5 24  5  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.85257985257985 %
# Average recall is: 66.15829346092504 %
# Average f1-score is: 64.39886284225906 %
#
# [[ 7  4  0  0]
#  [ 1  3  3  3]
#  [ 1  6  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 49.63241436925648 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.98484848484849 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 64.60526315789473 %
# Average f1-score is: 62.739425208937405 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 64.60526315789473 %
# Average f1-score is: 62.739425208937405 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 64.60526315789473 %
# Average f1-score is: 62.739425208937405 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 64.60526315789473 %
# Average f1-score is: 62.739425208937405 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 64.60526315789473 %
# Average f1-score is: 62.739425208937405 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[14 10  1  0]
#  [ 3 28  3  3]
#  [ 1  2 15  4]
#  [ 0  0  1 24]]
# Average precision is: 73.96437346437347 %
# Average recall is: 75.04928315412187 %
# Average f1-score is: 73.74660223497433 %
#
# [[ 8  2  1  0]
#  [ 3  2  3  2]
#  [ 2  4  6  3]
#  [ 0  1  2 11]]
# Average precision is: 52.82467532467532 %
# Average recall is: 50.627670940170944 %
# Precision for class: 0 is:  0.7272727272727273
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.4
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 51.374269005847964 %
# [[14 10  1  0]
#  [ 4 27  3  3]
#  [ 1  3 17  1]
#  [ 0  1  0 24]]
# Average precision is: 75.56142506142507 %
# Average recall is: 76.55113393239196 %
# Average f1-score is: 75.6257345112106 %
#
# [[ 7  4  0  0]
#  [ 3  2  3  2]
#  [ 2  5  6  2]
#  [ 0  2  2 10]]
# Average precision is: 48.76623376623377 %
# Average recall is: 49.92299367299368 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.4
# Precision for class: 3 is:  0.7142857142857143
# Average f1-score is: 48.960821786908745 %
# [[14 10  1  0]
#  [ 2 32  2  1]
#  [ 1  3 14  4]
#  [ 1  0  1 23]]
# Average precision is: 74.53071253071253 %
# Average recall is: 77.20238095238095 %
# Average f1-score is: 74.98937809694026 %
#
# [[ 8  3  0  0]
#  [ 1  5  3  1]
#  [ 2  7  4  2]
#  [ 0  1  2 11]]
# Average precision is: 56.99134199134199 %
# Average recall is: 56.74828643578643 %
# Precision for class: 0 is:  0.7272727272727273
# Precision for class: 1 is:  0.5
# Precision for class: 2 is:  0.26666666666666666
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 55.77339327339327 %
# [[14 10  1  0]
#  [ 2 32  2  1]
#  [ 1  3 14  4]
#  [ 1  0  1 23]]
# Average precision is: 74.53071253071253 %
# Average recall is: 77.20238095238095 %
# Average f1-score is: 74.98937809694026 %
#
# [[ 8  3  0  0]
#  [ 1  5  3  1]
#  [ 2  7  4  2]
#  [ 0  1  2 11]]
# Average precision is: 56.99134199134199 %
# Average recall is: 56.74828643578643 %
# Precision for class: 0 is:  0.7272727272727273
# Precision for class: 1 is:  0.5
# Precision for class: 2 is:  0.26666666666666666
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 55.77339327339327 %
# [[13 11  0  1]
#  [ 6 22  6  3]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 60.22850122850123 %
# Average recall is: 62.84722222222222 %
# Average f1-score is: 60.828294082345 %
#
# [[ 6  5  0  0]
#  [ 3  2  3  2]
#  [ 0  7  5  3]
#  [ 0  2  1 11]]
# Average precision is: 46.61255411255411 %
# Average recall is: 50.86805555555556 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.3333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 47.59615384615385 %
# [[13 11  0  1]
#  [ 6 22  6  3]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 60.22850122850123 %
# Average recall is: 62.84722222222222 %
# Average f1-score is: 60.828294082345 %
#
# [[ 6  5  0  0]
#  [ 3  2  3  2]
#  [ 0  7  5  3]
#  [ 0  2  1 11]]
# Average precision is: 46.61255411255411 %
# Average recall is: 50.86805555555556 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.3333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 47.59615384615385 %
# [[17  7  1  0]
#  [ 1 33  2  1]
#  [ 0  3 15  4]
#  [ 1  0  1 23]]
# Average precision is: 79.34275184275184 %
# Average recall is: 81.82702395523694 %
# Average f1-score is: 79.93397795255824 %
#
# [[ 6  4  1  0]
#  [ 0  6  3  1]
#  [ 2  4  6  3]
#  [ 0  1  2 11]]
# Average precision is: 58.27922077922077 %
# Average recall is: 59.583333333333336 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.6
# Precision for class: 2 is:  0.4
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 57.86610203670095 %
# [[13 11  1  0]
#  [ 5 23  3  6]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 65.71637426900585 %
# Average f1-score is: 62.75289147240366 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  3  6]
#  [ 0  8 11  3]
#  [ 1  3  0 21]]
# Average precision is: 62.04054054054053 %
# Average recall is: 65.71637426900585 %
# Average f1-score is: 62.75289147240366 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[14 10  1  0]
#  [ 1 32  2  2]
#  [ 1  1 16  4]
#  [ 1  0  1 23]]
# Average precision is: 76.8034398034398 %
# Average recall is: 79.0204726638049 %
# Average f1-score is: 77.01058201058201 %
#
# [[ 7  4  0  0]
#  [ 1  4  3  2]
#  [ 2  5  6  2]
#  [ 0  1  2 11]]
# Average precision is: 55.55194805194805 %
# Average recall is: 56.612554112554115 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.4
# Precision for class: 2 is:  0.4
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 55.50397877984084 %
# [[13 11  1  0]
#  [ 5 23  4  5]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.92395207546804 %
# Average f1-score is: 63.79931796598463 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[12 13  0  0]
#  [ 6 22  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 59.22850122850123 %
# Average recall is: 64.22237057455422 %
# Average f1-score is: 60.1082251082251 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 13  0  0]
#  [ 6 22  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 59.22850122850123 %
# Average recall is: 64.22237057455422 %
# Average f1-score is: 60.1082251082251 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 13  0  0]
#  [ 6 23  2  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 59.9041769041769 %
# Average recall is: 66.10197368421053 %
# Average f1-score is: 60.962566844919785 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  9  1  5]
#  [ 0  2  1 11]]
# Average precision is: 42.44588744588744 %
# Average recall is: 42.97514619883041 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.06666666666666667
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 40.64938747731397 %
# [[12 13  0  0]
#  [ 3 25  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 61.255528255528255 %
# Average recall is: 67.98076923076923 %
# Average f1-score is: 62.37858581004081 %
#
# [[ 6  5  0  0]
#  [ 0  5  3  2]
#  [ 0  8  2  5]
#  [ 0  2  1 11]]
# Average precision is: 49.11255411255411 %
# Average recall is: 54.861111111111114 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.5
# Precision for class: 2 is:  0.13333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 47.92979691876751 %
# [[12 13  0  0]
#  [ 4 24  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 60.57985257985258 %
# Average recall is: 66.62272601348232 %
# Average f1-score is: 61.615826034430675 %
#
# [[ 6  5  0  0]
#  [ 1  4  3  2]
#  [ 0  8  2  5]
#  [ 0  2  1 11]]
# Average precision is: 46.612554112554115 %
# Average recall is: 50.30284043441937 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.4
# Precision for class: 2 is:  0.13333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.51262315270935 %
# [[12 12  1  0]
#  [ 6 22  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 61.501228501228496 %
# Average recall is: 64.53947368421052 %
# Average f1-score is: 62.0969933250635 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 12  1  0]
#  [ 6 22  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 61.501228501228496 %
# Average recall is: 64.53947368421052 %
# Average f1-score is: 62.0969933250635 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 12  1  0]
#  [ 6 22  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 61.501228501228496 %
# Average recall is: 64.53947368421052 %
# Average f1-score is: 62.0969933250635 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 12  1  0]
#  [ 5 23  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 62.176904176904166 %
# Average recall is: 65.69444444444443 %
# Average f1-score is: 62.85826139111508 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 12  1  0]
#  [ 5 23  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 62.176904176904166 %
# Average recall is: 65.69444444444443 %
# Average f1-score is: 62.85826139111508 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[12 12  1  0]
#  [ 4 24  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 60.57985257985258 %
# Average recall is: 65.50420168067228 %
# Average f1-score is: 61.38315932433579 %
#
# [[ 6  5  0  0]
#  [ 1  4  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.27922077922078 %
# Average recall is: 52.976190476190474 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.4
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 47.81520562770562 %
# [[12 12  1  0]
#  [ 4 24  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 60.57985257985258 %
# Average recall is: 65.50420168067228 %
# Average f1-score is: 61.38315932433579 %
#
# [[ 6  5  0  0]
#  [ 1  4  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.27922077922078 %
# Average recall is: 52.976190476190474 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.4
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 47.81520562770562 %
# [[12 13  0  0]
#  [ 6 22  3  6]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 59.22850122850123 %
# Average recall is: 64.22237057455422 %
# Average f1-score is: 60.1082251082251 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[12 11  1  1]
#  [ 6 22  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 61.501228501228496 %
# Average recall is: 63.11964504283966 %
# Average f1-score is: 61.831830732544034 %
#
# [[ 6  5  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.77922077922077 %
# Average recall is: 49.15382819794585 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 45.350711057947905 %
# [[13 10  1  1]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.01682986536107 %
# Average f1-score is: 63.59319436890767 %
#
# [[ 7  4  0  0]
#  [ 2  2  3  3]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.55194805194805 %
# Average recall is: 44.94321468005678 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 43.741765480895914 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 1  6  5  3]
#  [ 0  2  1 11]]
# Average precision is: 51.38528138528138 %
# Average recall is: 53.57638888888889 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.3333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 51.416666666666664 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 1  6  5  3]
#  [ 0  2  1 11]]
# Average precision is: 51.38528138528138 %
# Average recall is: 53.57638888888889 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.3333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 51.416666666666664 %
# [[14  9  1  1]
#  [ 5 23  4  5]
#  [ 1  6 12  3]
#  [ 1  3  0 21]]
# Average precision is: 64.17690417690417 %
# Average recall is: 65.83811573409852 %
# Average f1-score is: 64.43650552346205 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 50.12400793650793 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 47.27491258741259 %
# [[12 12  0  1]
#  [ 5 23  6  3]
#  [ 0  9 10  3]
#  [ 1  3  0 21]]
# Average precision is: 59.9041769041769 %
# Average recall is: 63.27570921985816 %
# Average f1-score is: 60.6131800541283 %
#
# [[ 6  5  0  0]
#  [ 3  2  3  2]
#  [ 0  7  3  5]
#  [ 0  2  1 11]]
# Average precision is: 43.27922077922077 %
# Average recall is: 45.78373015873016 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 42.85183566433567 %
# [[13 11  1  0]
#  [ 5 23  6  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.40736310473153 %
# Average f1-score is: 63.79671217069591 %
#
# [[ 7  4  0  0]
#  [ 1  3  3  3]
#  [ 1  6  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 49.63241436925648 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.98484848484849 %
# [[13 11  1  0]
#  [ 6 23  5  3]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.42929292929293 %
# Average f1-score is: 63.83428300094967 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# [[13 11  1  0]
#  [ 5 23  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 66.42344497607655 %
# Average f1-score is: 63.85064091204442 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 1  6  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 48.492063492063494 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.67234848484849 %
# [[13 11  1  0]
#  [ 5 23  4  5]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 65.92395207546804 %
# Average f1-score is: 63.79931796598463 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 1  6  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 48.492063492063494 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.67234848484849 %
# [[13 11  1  0]
#  [ 6 22  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 62.5012285012285 %
# Average recall is: 65.2906976744186 %
# Average f1-score is: 63.07482721956406 %
#
# [[ 7  4  0  0]
#  [ 3  2  3  2]
#  [ 1  6  3  5]
#  [ 0  2  1 11]]
# Average precision is: 45.55194805194805 %
# Average recall is: 45.47258297258298 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.2
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 44.08143939393939 %
# [[13 11  1  0]
#  [ 5 23  3  6]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 63.176904176904166 %
# Average recall is: 66.42344497607655 %
# Average f1-score is: 63.85064091204442 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 1  6  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 48.492063492063494 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.67234848484849 %
# [[13 11  1  0]
#  [ 6 22  4  5]
#  [ 0  7 12  3]
#  [ 1  3  0 21]]
# Average precision is: 62.5012285012285 %
# Average recall is: 64.79120477381008 %
# Average f1-score is: 63.02350427350427 %
#
# [[ 7  4  0  0]
#  [ 2  3  3  2]
#  [ 2  5  3  5]
#  [ 0  2  1 11]]
# Average precision is: 48.051948051948045 %
# Average recall is: 47.25829725829726 %
# Precision for class: 0 is:  0.6363636363636364
# Precision for class: 1 is:  0.3
# Precision for class: 2 is:  0.2
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 46.16477272727273 %
# 0.4616477272727273

# %%
print(np.argmax(testScores))
# Out:
# 14

# %%
counter = 0
for i in testScores:
    print("Model ", counter, " has test score of ", i)
    counter+=1
# Out:
# Model  0  has test score of  0.43741765480895917
# Model  1  has test score of  0.43741765480895917
# Model  2  has test score of  0.4698484848484849
# Model  3  has test score of  0.4616477272727273
# Model  4  has test score of  0.4616477272727273
# Model  5  has test score of  0.4616477272727273
# Model  6  has test score of  0.4616477272727273
# Model  7  has test score of  0.4616477272727273
# Model  8  has test score of  0.5137426900584796
# Model  9  has test score of  0.4896082178690875
# Model  10  has test score of  0.5577339327339327
# Model  11  has test score of  0.5577339327339327
# Model  12  has test score of  0.4759615384615385
# Model  13  has test score of  0.4759615384615385
# Model  14  has test score of  0.5786610203670095
# Model  15  has test score of  0.4616477272727273
# Model  16  has test score of  0.4616477272727273
# Model  17  has test score of  0.5550397877984085
# Model  18  has test score of  0.4616477272727273
# Model  19  has test score of  0.453507110579479
# Model  20  has test score of  0.453507110579479
# Model  21  has test score of  0.40649387477313975
# Model  22  has test score of  0.4792979691876751
# Model  23  has test score of  0.4551262315270935
# Model  24  has test score of  0.453507110579479
# Model  25  has test score of  0.453507110579479
# Model  26  has test score of  0.453507110579479
# Model  27  has test score of  0.453507110579479
# Model  28  has test score of  0.453507110579479
# Model  29  has test score of  0.47815205627705626
# Model  30  has test score of  0.47815205627705626
# Model  31  has test score of  0.453507110579479
# Model  32  has test score of  0.4616477272727273
# Model  33  has test score of  0.4616477272727273
# Model  34  has test score of  0.453507110579479
# Model  35  has test score of  0.43741765480895917
# Model  36  has test score of  0.4616477272727273
# Model  37  has test score of  0.4616477272727273
# Model  38  has test score of  0.4616477272727273
# Model  39  has test score of  0.4616477272727273
# Model  40  has test score of  0.5141666666666667
# Model  41  has test score of  0.5141666666666667
# Model  42  has test score of  0.4727491258741259
# Model  43  has test score of  0.4285183566433567
# Model  44  has test score of  0.4698484848484849
# Model  45  has test score of  0.4616477272727273
# Model  46  has test score of  0.4667234848484849
# Model  47  has test score of  0.4667234848484849
# Model  48  has test score of  0.4408143939393939
# Model  49  has test score of  0.4667234848484849

# %%
plt.figure(figsize=(15,15))
plt.subplot(331)
plt.xlabel("Generations")
plt.ylabel("Standard deviation")
plt.title("Standard Deviation of Fitness Scores \n per Generation")
plt.plot(stdScoresAtEachEpoch)
plt.subplot(332)
plt.ylabel("Fitness score")
plt.xlabel("Generations")
plt.title("Mean Fitness Scores of Each Generation")
plt.plot(meanScoresAtEachEpoch)
plt.subplot(333)
plt.ylabel("F-Score")
plt.title("Testing Set F-Score of Best Model \n in Generation")
plt.xlabel("Generations")
plt.plot(testScores)

# %%
torch.manual_seed(tseed)
np.random.seed(npseed)

currentBestModel = hallOfFame[np.argmax(testScores)]
print(currentBestModel)
bestNetworkTrained = trainNetwork(currentBestModel, X, Y)

testAccra = testModel(bestNetworkTrained)
# Out:
# {'lr': 0.11965936830676609, 'neurons': array([ 7, 31]), 'dropout': array([0.00317593, 0.        ]), 'bias': True, 'epochs': 2666, 'inputsize': 7, 'outputsize': 4, 'activation': 0, 'lasthidden': 31}
# [[17  7  1  0]
#  [ 1 33  2  1]
#  [ 0  3 15  4]
#  [ 1  0  1 23]]
# Average precision is: 79.34275184275184 %
# Average recall is: 81.82702395523694 %
# Precision for class: 0 is:  0.68
# Precision for class: 1 is:  0.8918918918918919
# Precision for class: 2 is:  0.6818181818181818
# Precision for class: 3 is:  0.92
# Average f1-score is: 79.93397795255824 %
#
# [[ 6  4  1  0]
#  [ 0  6  3  1]
#  [ 2  4  6  3]
#  [ 0  1  2 11]]
# Average precision is: 58.27922077922077 %
# Average recall is: 59.583333333333336 %
# Precision for class: 0 is:  0.5454545454545454
# Precision for class: 1 is:  0.6
# Precision for class: 2 is:  0.4
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 57.86610203670095 %

# %%
def testModel(r_model):
    predTain = np.argmax(r_model(X).detach().numpy(), axis=1)
    targetTrain = Y.numpy()
    testConfusion = confusion_matrix(targetTrain, predTain)
    print(testConfusion)
    results = precision_recall_fscore_support(predTain, targetTrain)
    print("Average precision is:", (np.mean(results[0]) * 100), "%")
    print("Average recall is:", (np.mean(results[1]) * 100), "%")
    for i in range(0, 4):
        print("Precision for class:", i, "is: ", results[0][i])
    print("Average f1-score is:", (np.mean(results[2]) * 100), "%")
    print()
    
    predTest = np.argmax(r_model(X1).detach().numpy(), axis=1)
    targetTest = Y1.numpy()
    testConfusion = confusion_matrix(targetTest, predTest)
    print(testConfusion)
    results = precision_recall_fscore_support(predTest, targetTest)
    print("Average precision is:", (np.mean(results[0]) * 100), "%")
    print("Average recall is:", (np.mean(results[1]) * 100), "%")
    for i in range(0, 4):
        print("Precision for class:", i, "is: ", results[0][i])
    print("Average f1-score is:", (np.mean(results[2]) * 100), "%")
    
    return np.mean(results[2])

# %%
def testModelNoPrint(r_model):
    predTain = np.argmax(r_model(X).detach().numpy(), axis=1)
    targetTrain = Y.numpy()
    testConfusion = confusion_matrix(targetTrain, predTain)
    results = precision_recall_fscore_support(predTain, targetTrain)
    
    predTest = np.argmax(r_model(X1).detach().numpy(), axis=1)
    targetTest = Y1.numpy()
    testConfusion = confusion_matrix(targetTest, predTest)
    results = precision_recall_fscore_support(predTest, targetTest)
    
    return np.mean(results[2])

def trainModelNoPrint(r_model):
    predTain = np.argmax(r_model(X).detach().numpy(), axis=1)
    targetTrain = Y.numpy()
    testConfusion = confusion_matrix(targetTrain, predTain)
    results = precision_recall_fscore_support(predTain, targetTrain)
    return np.mean(results[2])

# %%
def dropNeuronBasedOnRelevanceTwoLayerNetwork(cmodelspec, cmodel, cbestacc):
    neuronToDrop = -1
    currentBestAcc = cbestacc
    bestModel = copy.deepcopy(cmodel)
    
    for i in range(0, cmodelspec['neurons'][0]):
        
        r_model = copy.deepcopy(cmodel)

        for p in r_model.children():
            for param in p.parameters():
                param[i] = 0
                break
            break

        newFOneScore = testModelNoPrint(r_model)

        if (newFOneScore > currentBestAcc): 
            currentBestAcc = newFOneScore
            neuronToDrop = i
            bestModel = r_model
            
    for i in range(0, cmodelspec['neurons'][1]):
        r_model = copy.deepcopy(cmodel)
        
        counter = 0
        
        for p in r_model.children():
            for param in p.parameters():
                if (counter == 2):
                    param[i] = 0
                    break
                counter+=1
            break

        newFOneScore = testModelNoPrint(r_model)

        if (newFOneScore > currentBestAcc): 
            currentBestAcc = newFOneScore
            neuronToDrop = i
            bestModel = r_model
    
    
        
    print("Dropped neuron: ", neuronToDrop)
    return bestModel

# %%
dickhead = dropNeuronBasedOnRelevanceTwoLayerNetwork(currentBestModel, bestNetworkTrained, testAccra)
for i in range(0, 20):
    dickhead = dropNeuronBasedOnRelevanceTwoLayerNetwork(currentBestModel, dickhead, testModelNoPrint(dickhead))

print(testModelNoPrint(dickhead))
print(testModelNoPrint(bestNetworkTrained))

testModel(dickhead)
# Out:
# Dropped neuron:  9
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# Dropped neuron:  -1
# 0.5992385057471263
# 0.5786610203670095
# [[16  7  2  0]
#  [ 1 33  2  1]
#  [ 0  3 15  4]
#  [ 0  0  1 24]]
# Average precision is: 79.34275184275184 %
# Average recall is: 82.15511344874757 %
# Precision for class: 0 is:  0.64
# Precision for class: 1 is:  0.8918918918918919
# Precision for class: 2 is:  0.6818181818181818
# Precision for class: 3 is:  0.96
# Average f1-score is: 79.75198412698413 %
#
# [[ 5  4  2  0]
#  [ 0  6  3  1]
#  [ 0  4  8  3]
#  [ 0  1  2 11]]
# Average precision is: 59.339826839826834 %
# Average recall is: 66.66666666666666 %
# Precision for class: 0 is:  0.45454545454545453
# Precision for class: 1 is:  0.6
# Precision for class: 2 is:  0.5333333333333333
# Precision for class: 3 is:  0.7857142857142857
# Average f1-score is: 59.92385057471263 %
# 0.5992385057471263

# %%
print(currentBestModel)
# Out:
# {'lr': 0.11965936830676609, 'neurons': array([ 7, 31]), 'dropout': array([0.00317593, 0.        ]), 'bias': True, 'epochs': 2666, 'inputsize': 7, 'outputsize': 4, 'activation': 0, 'lasthidden': 31}

# %%
modell = constructNetworkFromNNHyperparams(currentBestModel)
loss_func = nn.CrossEntropyLoss()
optimiser = torch.optim.SGD(modell.parameters(), lr=currentBestModel['lr'])

all_losses = list()

plt.ion()
testFScore = list()
trainFScore = list()

for t in range(0, 15000):
    # clear gradients for next train
    optimiser.zero_grad()
    # pass input x and get prediction
    prediction = modell.forward(X)
    # calculate loss
    loss = loss_func(prediction, Y.long())
    if (t % 200 == 0):
        print("loss:", loss)
    
    # perform backward pass
    loss.backward()
    
    trainFScore.append(trainModelNoPrint(modell))
    testFScore.append(testModelNoPrint(modell))
    all_losses.append(loss)
    # call the step function on an Optimiser makes an update to its
    # parameters
    optimiser.step()
modell.eval()
# Out:
# loss: tensor(1.3899, grad_fn=<NllLossBackward>)
# C:\Users\uilym\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# loss: tensor(1.0281, grad_fn=<NllLossBackward>)
# loss: tensor(0.8764, grad_fn=<NllLossBackward>)
# loss: tensor(0.8206, grad_fn=<NllLossBackward>)
# loss: tensor(0.7865, grad_fn=<NllLossBackward>)
# loss: tensor(0.7570, grad_fn=<NllLossBackward>)
# loss: tensor(0.7253, grad_fn=<NllLossBackward>)
# loss: tensor(0.6923, grad_fn=<NllLossBackward>)
# loss: tensor(0.6643, grad_fn=<NllLossBackward>)
# loss: tensor(0.6337, grad_fn=<NllLossBackward>)
# loss: tensor(0.6036, grad_fn=<NllLossBackward>)
# loss: tensor(0.5789, grad_fn=<NllLossBackward>)
# loss: tensor(0.5585, grad_fn=<NllLossBackward>)
# loss: tensor(0.5397, grad_fn=<NllLossBackward>)
# loss: tensor(0.5224, grad_fn=<NllLossBackward>)
# loss: tensor(0.5065, grad_fn=<NllLossBackward>)
# loss: tensor(0.4909, grad_fn=<NllLossBackward>)
# loss: tensor(0.4766, grad_fn=<NllLossBackward>)
# loss: tensor(0.4632, grad_fn=<NllLossBackward>)
# loss: tensor(0.4508, grad_fn=<NllLossBackward>)
# loss: tensor(0.4381, grad_fn=<NllLossBackward>)
# loss: tensor(0.4263, grad_fn=<NllLossBackward>)
# loss: tensor(0.4146, grad_fn=<NllLossBackward>)
# loss: tensor(0.4041, grad_fn=<NllLossBackward>)
# loss: tensor(0.3920, grad_fn=<NllLossBackward>)
# loss: tensor(0.3806, grad_fn=<NllLossBackward>)
# loss: tensor(0.3711, grad_fn=<NllLossBackward>)
# loss: tensor(0.3625, grad_fn=<NllLossBackward>)
# loss: tensor(0.3542, grad_fn=<NllLossBackward>)
# loss: tensor(0.3439, grad_fn=<NllLossBackward>)
# loss: tensor(0.3348, grad_fn=<NllLossBackward>)
# loss: tensor(0.3266, grad_fn=<NllLossBackward>)
# loss: tensor(0.3154, grad_fn=<NllLossBackward>)
# loss: tensor(0.3123, grad_fn=<NllLossBackward>)
# loss: tensor(0.3009, grad_fn=<NllLossBackward>)
# loss: tensor(0.2881, grad_fn=<NllLossBackward>)
# loss: tensor(0.2783, grad_fn=<NllLossBackward>)
# loss: tensor(0.2652, grad_fn=<NllLossBackward>)
# loss: tensor(0.2567, grad_fn=<NllLossBackward>)
# loss: tensor(0.2487, grad_fn=<NllLossBackward>)
# loss: tensor(0.2390, grad_fn=<NllLossBackward>)
# loss: tensor(0.2339, grad_fn=<NllLossBackward>)
# loss: tensor(0.2292, grad_fn=<NllLossBackward>)
# loss: tensor(0.2250, grad_fn=<NllLossBackward>)
# loss: tensor(0.2209, grad_fn=<NllLossBackward>)
# loss: tensor(0.2171, grad_fn=<NllLossBackward>)
# loss: tensor(0.2135, grad_fn=<NllLossBackward>)
# loss: tensor(0.2103, grad_fn=<NllLossBackward>)
# loss: tensor(0.2071, grad_fn=<NllLossBackward>)
# loss: tensor(0.2042, grad_fn=<NllLossBackward>)
# loss: tensor(0.2015, grad_fn=<NllLossBackward>)
# loss: tensor(0.1990, grad_fn=<NllLossBackward>)
# loss: tensor(0.1966, grad_fn=<NllLossBackward>)
# loss: tensor(0.1943, grad_fn=<NllLossBackward>)
# loss: tensor(0.1921, grad_fn=<NllLossBackward>)
# loss: tensor(0.1900, grad_fn=<NllLossBackward>)
# loss: tensor(0.1881, grad_fn=<NllLossBackward>)
# loss: tensor(0.1862, grad_fn=<NllLossBackward>)
# loss: tensor(0.1842, grad_fn=<NllLossBackward>)
# loss: tensor(0.1825, grad_fn=<NllLossBackward>)
# loss: tensor(0.1808, grad_fn=<NllLossBackward>)
# loss: tensor(0.1793, grad_fn=<NllLossBackward>)
# loss: tensor(0.1777, grad_fn=<NllLossBackward>)
# loss: tensor(0.1762, grad_fn=<NllLossBackward>)
# loss: tensor(0.1747, grad_fn=<NllLossBackward>)
# loss: tensor(0.1734, grad_fn=<NllLossBackward>)
# loss: tensor(0.1721, grad_fn=<NllLossBackward>)
# loss: tensor(0.1710, grad_fn=<NllLossBackward>)
# loss: tensor(0.1698, grad_fn=<NllLossBackward>)
# loss: tensor(0.1687, grad_fn=<NllLossBackward>)
# loss: tensor(0.1676, grad_fn=<NllLossBackward>)
# loss: tensor(0.1667, grad_fn=<NllLossBackward>)
# loss: tensor(0.1658, grad_fn=<NllLossBackward>)
# loss: tensor(0.1648, grad_fn=<NllLossBackward>)
# loss: tensor(0.1640, grad_fn=<NllLossBackward>)
# HyperNetwork(
#   (hidden): ModuleList(
#     (0): Linear(in_features=7, out_features=7, bias=True)
#     (1): Linear(in_features=7, out_features=31, bias=True)
#   )
#   (drops): ModuleList(
#     (0): Dropout(p=0.0031759320497093406)
#     (1): Dropout(p=0.0)
#   )
#   (out): Linear(in_features=31, out_features=4, bias=True)
# )

# %%
plt.figure(figsize=(10,10))
# plt.subplot(331)
plt.plot(all_losses, label='Training Loss')
plt.plot(testFScore, label="Testing F-Score")
plt.plot(trainFScore, label='Training F-Score')
plt.legend(loc="upper right")
plt.xlim([0,14000])
plt.title("Plot of scores and loss against epochs trained")
plt.xlabel("epochs")
# Out:
# Text(0.5,0,'epochs')
